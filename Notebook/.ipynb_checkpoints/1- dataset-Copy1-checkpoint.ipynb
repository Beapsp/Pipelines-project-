# %%
import requests 
import json
import os
from dotenv import load_dotenv
import pandas as pd
from pandas import json_normalize

# %%
# !pip3 install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /home/beatrizsp/anaconda3/lib/python3.8/site-packages (0.19.1)

# %% [markdown]
# ### 1. Importo mi dataframe

# %%
df= pd.read_csv("../data/Food and Calories.csv")

# %%
#url = "https://www.fruityvice.com/api/fruit/all"

# %%
#response = requests.get(url)

# %%
#response

# %%
#res_js= response.json()

# %%
#res_js

# %%
#len(res_js)

# %%
#res_js[0]

# %%
df.head()
# Out:
#         Food              Serving Calories
# 0  Artichoke  1 artichoke (128 g)   60 cal
# 1    Arugula         1 leaf (2 g)    1 cal
# 2  Asparagus       1 spear (12 g)    2 cal
# 3  Aubergine  1 aubergine (458 g)  115 cal
# 4   Beetroot        1 beet (82 g)   35 cal

# %% [markdown]
# ### Limpio mi data frame eliminando nulos y duplicados

# %%
df.shape
# Out:
# (562, 3)

# %%
df.dropna(how="all", inplace=True)

# %%
df.shape #no hay ninguna fila entera de NaN
# Out:
# (562, 3)

# %%
duplicates= df.drop_duplicates() #elimino los duplicados

# %%
duplicates.shape
# Out:
# (549, 3)

# %%
food = duplicates["Food"].unique()

# %% [markdown]
# ### Obtengo una lista con los valores únicos de la columna Food que serán los valores de mi dataframe que utilizaré con la información de la API con la que trabaje a continuación

# %%
lista_food= list(food)

# %%
type(lista_food)
# Out:
# list

# %%
lista_food
# Out:
# ['Artichoke',
#  'Arugula',
#  'Asparagus',
#  'Aubergine',
#  'Beetroot',
#  'Bell Pepper',
#  'Black Olives',
#  'Broccoli',
#  'Brussels Sprouts',
#  'Cabbage',
#  'Capsicum',
#  'Carrot',
#  'Cauliflower',
#  'Celery',
#  'Chard',
#  'Cherry Tomato',
#  'Chicory',
#  'Chinese Cabbage',
#  'Chives',
#  'Collard Greens',
#  'Corn',
#  'Courgette',
#  'Creamed Spinach',
#  'Cucumber',
#  'Eggplant',
#  'Endive',
#  'Fennel',
#  'Garlic',
#  'Gherkin',
#  'Gourd',
#  'Green Beans',
#  'Green Olives',
#  'Green Onion',
#  'Horseradish',
#  'Kale',
#  'Kohlrabi',
#  'Kumara',
#  'Leek',
#  'Lettuce',
#  'Mushrooms',
#  'Mustard Greens',
#  'Nori',
#  'Okra',
#  'Olives',
#  'Onion',
#  'Parsnips',
#  'Peas',
#  'Pepper',
#  'Potato',
#  'Pumpkin',
#  'Radishes',
#  'Red Cabbage',
#  'Rutabaga',
#  'Shallots',
#  'Spinach',
#  'Squash',
#  'Sweet Potato',
#  'Tomato',
#  'Turnip Greens',
#  'Turnips',
#  'Wasabi',
#  'Winter Squash',
#  'Zucchini',
#  'Acai',
#  'Apple',
#  'Applesauce',
#  'Apricot',
#  'Avocado',
#  'Banana',
#  'Blackberries',
#  'Blood Oranges',
#  'Blueberries',
#  'Cantaloupe',
#  'Cherries',
#  'Clementine',
#  'Cranberries',
#  'Currants',
#  'Custard Apple',
#  'Dates',
#  'Figs',
#  'Fruit salad',
#  'Grapes',
#  'Greengage',
#  'Guava',
#  'Jackfruit',
#  'Jujube',
#  'Kiwi',
#  'Lemon',
#  'Lime',
#  'Lychees',
#  'Mandarin Oranges',
#  'Mango',
#  'Minneola',
#  'Mulberries',
#  'Nectarine',
#  'Orange',
#  'Papaya',
#  'Passion Fruit',
#  'Peach',
#  'Pear',
#  'Persimmon',
#  'Physalis',
#  'Pineapple',
#  'Plantains',
#  'Plum',
#  'Pomegranate',
#  'Quince',
#  'Raisins',
#  'Rambutan',
#  'Raspberries',
#  'Rhubarb',
#  'Starfruit',
#  'Strawberries',
#  'Tamarind',
#  'Tangerine',
#  'Watermelon',
#  'Baby Back Ribs',
#  'Bacon and Eggs',
#  'Baked Beans',
#  'BBQ Ribs',
#  'Beef Stew',
#  'Biryani',
#  'Black Pudding',
#  'Black Rice',
#  'BLT',
#  'Brown Rice',
#  'Burrito',
#  'Butter Chicken',
#  'California Roll',
#  'Chicken Caesar Salad',
#  'Chicken Fried Steak',
#  'Chicken Marsala',
#  'Chicken Parmesan',
#  'Chicken Pot Pie',
#  'Chicken Tikka Masala',
#  'Chili con Carne',
#  'Chimichanga',
#  'Cobb Salad',
#  'Corn Dog',
#  'Corned Beef Hash',
#  'Cottage Pie',
#  'Dal',
#  'Deviled Eggs',
#  'Dim Sum',
#  'Dosa',
#  'Enchiladas',
#  'Fajita',
#  'Fish and Chips',
#  'Fried Rice',
#  'Fried Shrimp',
#  'Grilled Cheese Sandwich',
#  'Ham and Cheese Sandwich',
#  'Hummus',
#  'Jambalaya',
#  'Kebab',
#  'Lasagne',
#  'Mac and Cheese',
#  'Macaroni and Cheese',
#  'Mashed Potatoes',
#  'Meat Pie',
#  'Meatloaf',
#  'Naan',
#  'Orange Chicken',
#  'Pad Thai',
#  'Paella',
#  'Paratha',
#  'Pea Soup',
#  'Peanut Butter Sandwich',
#  'Peking Duck',
#  'Philly Cheese Steak',
#  'Pizza',
#  'Pork Chop',
#  'Potato Salad',
#  'Pulled Pork Sandwich',
#  'Ramen',
#  'Ravioli',
#  'Reuben Sandwich',
#  'Roast Beef',
#  'Roast Dinner',
#  'Samosa',
#  'Sausage Roll',
#  'Sausage Rolls',
#  'Shepherds Pie',
#  'Shrimp Cocktail',
#  'Sloppy Joe',
#  'Sloppy Joes',
#  'Spaghetti Bolognese',
#  'Spring Roll',
#  'Spring Rolls',
#  'Taco',
#  'Tandoori Chicken',
#  'Yorkshire Pudding',
#  'Amaranth',
#  'Barley',
#  'Barley Groats',
#  'Buckwheat',
#  'Buckwheat Groats',
#  'Corn Waffles',
#  'Cornmeal',
#  'Cornstarch',
#  'Couscous',
#  'Cracker',
#  'Durum Wheat Semolina',
#  'Flaxseed',
#  'Freekeh',
#  'Gluten',
#  'Grissini',
#  'Kamut',
#  'Millet',
#  'Millet Flour',
#  'Millet Gruel',
#  'Oat Bran',
#  'Pearl Barley',
#  'Polenta',
#  'Prawn Crackers',
#  'Pretzel Sticks',
#  'Quinoa',
#  'Rusk',
#  'Rye Bran',
#  'Sago',
#  'Savoury Biscuits',
#  'Shortbread',
#  'Spelt',
#  'Spelt Bran',
#  'Spelt Semolina',
#  'Sunflower Seeds',
#  'Tortilla',
#  'Tortilla Chips',
#  'Wheat Bran',
#  'Wheat Germ',
#  'Wheat Gluten',
#  'Wheat Semolina',
#  'Wheat Starch',
#  'Whole Grain Wheat',
#  'Wholegrain Oat',
#  'Almond Oil',
#  'Apricot Kernel Oil',
#  'Argan Oil',
#  'Avocado Oil',
#  'Babassu Oil',
#  'Canola Oil',
#  'Coconut Oil',
#  'Corn Oil',
#  'Cottonseed Oil',
#  'Flaxseed Oil',
#  'Grape Seed Oil',
#  'Hazelnut Oil',
#  'Linseed Oil',
#  'Menhaden Oil',
#  'Mustard Oil',
#  'Oat Oil',
#  'Olive Oil',
#  'Palm Kernel Oil',
#  'Palm Oil',
#  'Peanut Oil',
#  'Poppy Seed Oil',
#  'Pumpkin Seed Oil',
#  'Rice Bran Oil',
#  'Safflower Oil',
#  'Salmon Oil',
#  'Sesame Oil',
#  'Shea Oil',
#  'Soy Oil',
#  'Sunflower Oil',
#  'Tomato Seed Oil',
#  'Vegetable Oil',
#  'Walnut Oil',
#  'Wheat Germ Oil',
#  'Alphabet Soup',
#  'Bean Stew',
#  'Beef Bouillon',
#  'Beef Noodle Soup',
#  'Beef Soup',
#  'Bouillon',
#  'Broccoli Cheese Soup',
#  'Broccoli Soup',
#  'Cabbage Soup',
#  'Carrot Ginger Soup',
#  'Carrot Soup',
#  'Chicken Bouillon',
#  'Chicken Broth',
#  'Chicken Gumbo Soup',
#  'Chicken Noodle Soup',
#  'Chicken Stock',
#  'Chicken Vegetable Soup',
#  'Chicken with Rice Soup',
#  'Cream of Asparagus Soup',
#  'Cream of Broccoli Soup',
#  'Cream of Celery Soup',
#  'Cream of Chicken Soup',
#  'Cream of Mushroom Soup',
#  'Cream of Onion Soup',
#  'Cream of Potato Soup',
#  'Creamy Chicken Noodle Soup',
#  'French Onion Soup',
#  'Golden Mushroom Soup',
#  'Goulash',
#  'Instant Ramen',
#  'Lentil Soup',
#  'Lobster Bisque Soup',
#  'Meatball Soup',
#  'Minestrone',
#  'Mushroom Soup',
#  'Noodle Soup',
#  'Onion Soup',
#  'Oxtail Soup',
#  'Potato Soup',
#  'Pumpkin Soup',
#  'Scotch Broth',
#  'Succotash',
#  'Thai Soup',
#  'Tomato Rice Soup',
#  'Tomato Soup',
#  'Vegetable Beef Soup',
#  'Vegetable Broth',
#  'Vegetable Soup',
#  'Vegetable Stock',
#  'Wedding Soup',
#  'Baskin-Robbins',
#  'Ben and Jerry’s',
#  'Butter Pecan Ice Cream',
#  'Carvel',
#  'Chocolate Chip Ice Cream',
#  'Chocolate Ice Cream',
#  'Ciao Bella',
#  'Coffee Ice Cream',
#  'Cold Stone Creamery',
#  'Cookie Dough Ice Cream',
#  'Crunchie McFlurry',
#  'Dairy Milk McFlurry',
#  'Dippin Dots',
#  'Double Rainbow',
#  'Drumsticks',
#  'French Vanilla Ice Cream',
#  'Friendly’s',
#  'Healthy Choice',
#  'Hot Fudge Sundae',
#  'Ice Cream Sandwich',
#  'Ice Cream Sundae',
#  'Ice Milk',
#  'Magnolia',
#  'Magnum',
#  'Magnum Almond',
#  'Magnum Double Caramel',
#  'Magnum Double Chocolate',
#  'Magnum Gold',
#  'Magnum White',
#  'McFlurry',
#  'McFlurry Oreo',
#  'Mini Milk',
#  'Mint Chocolate Chip Ice Cream',
#  'Rocky Road Ice Cream',
#  'Schwan’s',
#  'Smarties McFlurry',
#  'Snickers Ice Cream',
#  'Soft Serve',
#  'Solero',
#  'Strawberry Ice Cream',
#  'Strawberry Sundae',
#  'Sundae',
#  'Turkey Hill',
#  'Vanilla Cone',
#  'Vanilla Ice Cream',
#  'Cannelloni',
#  'Capellini',
#  'Cappelletti',
#  'Cellophane Noodles',
#  'Cheese Tortellini',
#  'Dampfnudel',
#  'Dumpling Dough',
#  'Egg Noodles',
#  'Farfalle',
#  'Fettuccine',
#  'Fusilli',
#  'Glass Noodles',
#  'Lasagne Sheets',
#  'Linguine',
#  'Low Carb Pasta',
#  'Macaroni',
#  'Manicotti',
#  'Mostaccioli',
#  'Orecchiette',
#  'Orzo',
#  'Penne',
#  'Penne Rigate',
#  'Pierogi',
#  'Rigatoni',
#  'Rotini',
#  'Shells',
#  'Shirataki Noodles',
#  'Soy Noodles',
#  'Spaetzle',
#  'Spaghetti',
#  'Spinach Tortellini',
#  'Spirelli',
#  'Tagliatelle',
#  'Tortellini',
#  'Vermicelli',
#  'Whole Grain Noodles',
#  'Whole Grain Spaghetti',
#  'Ziti',
#  'BBQ Chicken Pizza',
#  'BBQ Pizza',
#  'Beef Pizza',
#  'Bianca Pizza',
#  'Buffalo Chicken Pizza',
#  'Calabrese Pizza',
#  'Calzone',
#  'Capricciosa Pizza',
#  'Cheese Pizza',
#  'Chicken Pizza',
#  'Deep Dish Pizza',
#  'Dominos Philly Cheese Steak Pizza',
#  'Four Cheese Pizza',
#  'Goat Cheese Pizza',
#  'Grilled Pizza',
#  'Hawaiian Pizza',
#  'Margherita Pizza',
#  'Mozzarella Pizza',
#  'Mushroom Pizza',
#  'Napoli Pizza',
#  'New York Style Pizza',
#  'Pepperoni Pizza',
#  'Pizza Dough',
#  'Pizza Hut Stuffed Crust Pizza',
#  'Pizza Hut Supreme Pizza',
#  'Pizza Rolls',
#  'Quattro Formaggi Pizza',
#  'Red Pepper Pizza',
#  'Salami Pizza',
#  'Sausage Pizza',
#  'Seafood Pizza',
#  'Shrimp Pizza',
#  'Sicilian Pizza',
#  'Spinach Feta Pizza',
#  'Spinach Pizza',
#  'Stuffed Crust Pizza',
#  'Tarte Flambée',
#  'Thin Crust Pizza',
#  'Tuna Pizza',
#  'Vegetable Pizza',
#  'Vegetarian Pizza',
#  'Veggie Pizza',
#  'White Pizza',
#  'Acerola',
#  'Asian Pear',
#  'Breadfruit',
#  'Cantaloupe Melon',
#  'Casaba Melon',
#  'Cherimoya',
#  'Dragon Fruit',
#  'Durian',
#  'Feijoa',
#  'Galia Melon',
#  'Grapefruit',
#  'Honeydew',
#  'Kumquat',
#  'Lychee',
#  'Mangosteen',
#  'Maracuya',
#  'Maraschino Cherries',
#  'Muskmelon',
#  'Noni',
#  'Pink Grapefruit',
#  'Plantain',
#  'Pomelo',
#  'Prickly Pear',
#  'Sapodilla',
#  'Soursop Fruit',
#  'Star Fruit',
#  'Arby’s Grand Turkey Club',
#  'Arby’s Reuben',
#  'Arby’s Roast Beef Classic',
#  'Arby’s Roast Beef Max',
#  'BBQ Rib',
#  'Bean Burrito',
#  'Big N’ Tasty',
#  'Bratwurst',
#  'Burger King Angry Whopper',
#  'Burger King Double Whopper',
#  'Burger King Double Whopper with Cheese',
#  'Burger King Original Chicken Sandwich',
#  'Burger King Premium Alaskan Fish Sandwich',
#  'Burger King Triple Whopper',
#  'Burger King Whopper',
#  'Burger King Whopper Jr.',
#  'Burger King Whopper with Cheese',
#  'Cheeseburger',
#  'Chicken Breast',
#  'Chicken Fajita',
#  'Chicken McNuggets',
#  'Chicken Nuggets',
#  'Chicken Pizziola',
#  'Chicken Sandwich',
#  'Chicken Teriyaki Sandwich',
#  'Chicken Wings',
#  'Chop Suey',
#  'Curly Fries',
#  'Double Cheeseburger',
#  'Egg Roll',
#  'Falafel',
#  'Filet-o-Fish',
#  'Fish Sandwich',
#  'French Fries',
#  'Grilled Chicken Salad',
#  'Ham Sandwich',
#  'Hamburger',
#  'Hot Dog',
#  'Italian BMT',
#  'Lasagna',
#  'McDonald’s Big Mac',
#  'McDonald’s Cheeseburger',
#  'McDonald’s Chicken Nuggets',
#  'McDonald’s Double Cheeseburger',
#  'McDonald’s Filet-o-Fish',
#  'McDonald’s McChicken',
#  'McDonald’s McDouble',
#  'McDonald’s McMuffi Egg',
#  'McDonald’s McRib',
#  'McDonald’s Mighty Wings',
#  'McRib',
#  'Meatball Sandwich',
#  'Nachos with Cheese',
#  'Onion Rings',
#  'Poutine',
#  'Smoked Salmon',
#  'Spicy Italian',
#  'Subway Club Sandwich',
#  'Tortilla Wrap',
#  'Tuna',
#  'Turkey',
#  'Veggie Burger',
#  'Veggie Delight',
#  'Veggie Patty',
#  'Wendy’s Baconator',
#  'Wendy’s Jr. Bacon Cheeseburger',
#  'Wendy’s Jr. Cheeseburger',
#  'Wendy’s Son of Baconator',
#  'Whopper',
#  'Zinger',
#  'Zinger Burger']

# %%
type(lista_food)
# Out:
# list

# %%
len(lista_food)
# Out:
# 541

# %%
#tengo una url de API pero la llamo concretamente para un alimento, hago una PRUEBA para que ver qué me devuelve introduciendo un alimento que sé (porque está en español) que no va a estar en la lista de APIs.

# %%
#url_nut = 'https://api.edamam.com/api/nutrition-data?app_id=5bb5f3ad&app_key=a3a514dbb62d9ea04d57160922fce573&nutrition-type=logging&ingr=manzana'

# %%
#apple = requests.get(url_nut)

# %%
#manzana = apple.json()

# %%
#df = pd.DataFrame.from_dict(manzana, orient="index")

# %%
#df. Me devuelve un dataframe con los valores vacío pero no me da error.

# %%
#url2= 'https://api.edamam.com/api/nutrition-data'

# %% [markdown]
# ### Me devuelve un json pero cuando meto la url entera con los 3 parámetros, app_id, app_key, ingr ; pero solo me devuelve un 200 cuando meto un ingrediente concreto, en este caso "apple"

# %%
url2 = 'https://api.edamam.com/api/nutrition-data?app_id=5bb5f3ad&app_key=a3a514dbb62d9ea04d57160922fce573&nutrition-type=logging&ingr=apple'

# %%
parameters = {"app_id": '5bb5f3ad', "app_key":'a3a514dbb62d9ea04d57160922fce573', "ingr":"apple"}

# %%
response2 = requests.get(url2, params=parameters)

# %%
response2
# Out:
# <Response [200]>

# %%
api=response2.json()

# %%
api #me da los valores de apple
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_337dab2003e64f4a8f2d0ca4301c1469',
#  'calories': 125,
#  'totalWeight': 242.0,
#  'dietLabels': ['LOW_FAT', 'LOW_SODIUM'],
#  'healthLabels': ['FAT_FREE',
#   'LOW_FAT_ABS',
#   'LOW_POTASSIUM',
#   'KIDNEY_FRIENDLY',
#   'VEGAN',
#   'VEGETARIAN',
#   'PESCATARIAN',
#   'PALEO',
#   'SPECIFIC_CARBS',
#   'MEDITERRANEAN',
#   'DASH',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE',
#   'KOSHER'],
#  'cautions': ['SULFITES'],
#  'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 125.84,
#    'unit': 'kcal'},
#   'FAT': {'label': 'Total lipid (fat)',
#    'quantity': 0.41140000000000004,
#    'unit': 'g'},
#   'FASAT': {'label': 'Fatty acids, total saturated',
#    'quantity': 0.06776,
#    'unit': 'g'},
#   'FAMS': {'label': 'Fatty acids, total monounsaturated',
#    'quantity': 0.01694,
#    'unit': 'g'},
#   'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#    'quantity': 0.12341999999999999,
#    'unit': 'g'},
#   'CHOCDF': {'label': 'Carbohydrate, by difference',
#    'quantity': 33.4202,
#    'unit': 'g'},
#   'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 5.808, 'unit': 'g'},
#   'SUGAR': {'label': 'Sugars, total',
#    'quantity': 25.143800000000002,
#    'unit': 'g'},
#   'PROCNT': {'label': 'Protein', 'quantity': 0.6292, 'unit': 'g'},
#   'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#   'NA': {'label': 'Sodium, Na', 'quantity': 2.42, 'unit': 'mg'},
#   'CA': {'label': 'Calcium, Ca', 'quantity': 14.52, 'unit': 'mg'},
#   'MG': {'label': 'Magnesium, Mg', 'quantity': 12.1, 'unit': 'mg'},
#   'K': {'label': 'Potassium, K', 'quantity': 258.94, 'unit': 'mg'},
#   'FE': {'label': 'Iron, Fe', 'quantity': 0.2904, 'unit': 'mg'},
#   'ZN': {'label': 'Zinc, Zn', 'quantity': 0.0968, 'unit': 'mg'},
#   'P': {'label': 'Phosphorus, P',
#    'quantity': 26.619999999999997,
#    'unit': 'mg'},
#   'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 7.26, 'unit': 'µg'},
#   'VITC': {'label': 'Vitamin C, total ascorbic acid',
#    'quantity': 11.132,
#    'unit': 'mg'},
#   'THIA': {'label': 'Thiamin', 'quantity': 0.04114, 'unit': 'mg'},
#   'RIBF': {'label': 'Riboflavin',
#    'quantity': 0.06291999999999999,
#    'unit': 'mg'},
#   'NIA': {'label': 'Niacin', 'quantity': 0.22022, 'unit': 'mg'},
#   'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.09922, 'unit': 'mg'},
#   'FOLDFE': {'label': 'Folate, DFE', 'quantity': 7.26, 'unit': 'µg'},
#   'FOLFD': {'label': 'Folate, food', 'quantity': 7.26, 'unit': 'µg'},
#   'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#   'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#   'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#   'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#    'quantity': 0.4356,
#    'unit': 'mg'},
#   'VITK1': {'label': 'Vitamin K (phylloquinone)',
#    'quantity': 5.324,
#    'unit': 'µg'},
#   'WATER': {'label': 'Water', 'quantity': 207.0552, 'unit': 'g'}},
#  'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 6.292,
#    'unit': '%'},
#   'FAT': {'label': 'Fat', 'quantity': 0.632923076923077, 'unit': '%'},
#   'FASAT': {'label': 'Saturated', 'quantity': 0.3388, 'unit': '%'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 11.140066666666666, 'unit': '%'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 23.232, 'unit': '%'},
#   'PROCNT': {'label': 'Protein', 'quantity': 1.2584, 'unit': '%'},
#   'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#   'NA': {'label': 'Sodium', 'quantity': 0.10083333333333333, 'unit': '%'},
#   'CA': {'label': 'Calcium', 'quantity': 1.452, 'unit': '%'},
#   'MG': {'label': 'Magnesium', 'quantity': 2.880952380952381, 'unit': '%'},
#   'K': {'label': 'Potassium', 'quantity': 5.509361702127659, 'unit': '%'},
#   'FE': {'label': 'Iron', 'quantity': 1.6133333333333333, 'unit': '%'},
#   'ZN': {'label': 'Zinc', 'quantity': 0.88, 'unit': '%'},
#   'P': {'label': 'Phosphorus', 'quantity': 3.802857142857142, 'unit': '%'},
#   'VITA_RAE': {'label': 'Vitamin A',
#    'quantity': 0.8066666666666666,
#    'unit': '%'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 12.36888888888889, 'unit': '%'},
#   'THIA': {'label': 'Thiamin (B1)',
#    'quantity': 3.4283333333333332,
#    'unit': '%'},
#   'RIBF': {'label': 'Riboflavin (B2)',
#    'quantity': 4.839999999999999,
#    'unit': '%'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 1.376375, 'unit': '%'},
#   'VITB6A': {'label': 'Vitamin B6',
#    'quantity': 7.632307692307693,
#    'unit': '%'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 1.815,
#    'unit': '%'},
#   'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#   'TOCPHA': {'label': 'Vitamin E',
#    'quantity': 2.9040000000000004,
#    'unit': '%'},
#   'VITK1': {'label': 'Vitamin K',
#    'quantity': 4.4366666666666665,
#    'unit': '%'}},
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 125,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
#    'quantity': 2,
#    'unit': 'kcal'},
#   'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 3, 'unit': 'kcal'},
#   'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#    'quantity': 120,
#    'unit': 'kcal'}}}

# %%
type(api)
# Out:
# dict

# %% [markdown]
# ### Voy a hacer una prueba con una lista de 3 ingredientes, para que en la función me itere por la lista. De esos tres ingredientes se que uno no va a estar en la api porque está en español pero los otros dos si.

# %%
lista2 = ["manzana", "pear", "lemon"]

# %%
def call_api(app_id, app_key, ingredientes):
    result_list = []
    for ingre in ingredientes: 
        b = requests.get(f'https://api.edamam.com/api/nutrition-data?app_id={app_id}&app_key={app_key}&nutrition-type=logging&ingr={ingre}').content
        r = json.loads(b.decode())
        result_list.append(r)
    return result_list

# %%
prueba = call_api('5bb5f3ad','a3a514dbb62d9ea04d57160922fce573',lista2)

# %%
d = pd.DataFrame(prueba)
d.drop(["dietLabels", "calories", "uri", "totalDaily", "totalNutrientsKCal"], axis = 1, inplace = True )
d["ingredient"] = lista2
d.head()
# Out:
#    totalWeight                                       healthLabels    cautions  \
# 0          0.0  [LOW_SUGAR, VEGAN, VEGETARIAN, PESCATARIAN, PA...          []
# 1        166.0  [FAT_FREE, LOW_FAT_ABS, LOW_POTASSIUM, KIDNEY_...  [SULFITES]
# 2         58.0  [FAT_FREE, LOW_FAT_ABS, SUGAR_CONSCIOUS, LOW_P...  [SULFITES]
#
#                                       totalNutrients ingredient
# 0                                                 {}    manzana
# 1  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...       pear
# 2  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...      lemon

# %%
def remove_col(x):
    try:
        return x[0]
    except:
        return "no info"
    
d["cautions"] = d["cautions"].apply(remove_col)

def health(x):
    try:
        return x[:]
    except:
        return "no info"
    
d["healthLabels"] = d["healthLabels"].apply(health)

# %%
d.head(50)
# Out:
#    totalWeight             healthLabels cautions  \
# 0          0.0       [LOW_SUGAR, VEGAN]        n
# 1        166.0  [FAT_FREE, LOW_FAT_ABS]        S
# 2         58.0  [FAT_FREE, LOW_FAT_ABS]        S
#
#                                       totalNutrients ingredient
# 0                                                 {}    manzana
# 1  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...       pear
# 2  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...      lemon

# %%
info = d["totalNutrients"].apply(pd.Series)

# %%
d.head()
# Out:
#    totalWeight                                       healthLabels    cautions  \
# 0          0.0  [LOW_SUGAR, VEGAN, VEGETARIAN, PESCATARIAN, PA...          []
# 1        166.0  [FAT_FREE, LOW_FAT_ABS, LOW_POTASSIUM, KIDNEY_...  [SULFITES]
# 2         58.0  [FAT_FREE, LOW_FAT_ABS, SUGAR_CONSCIOUS, LOW_P...  [SULFITES]
#
#                                       totalNutrients
# 0                                                 {}
# 1  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...
# 2  {'ENERC_KCAL': {'label': 'Energy', 'quantity':...

# %%
d["totalNutrients"][1]
# Out:
# {'ENERC_KCAL': {'label': 'Energy', 'quantity': 94.62, 'unit': 'kcal'},
#  'FAT': {'label': 'Total lipid (fat)',
#   'quantity': 0.23240000000000005,
#   'unit': 'g'},
#  'FASAT': {'label': 'Fatty acids, total saturated',
#   'quantity': 0.036520000000000004,
#   'unit': 'g'},
#  'FAMS': {'label': 'Fatty acids, total monounsaturated',
#   'quantity': 0.13944,
#   'unit': 'g'},
#  'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#   'quantity': 0.15604,
#   'unit': 'g'},
#  'CHOCDF': {'label': 'Carbohydrate, by difference',
#   'quantity': 25.281800000000004,
#   'unit': 'g'},
#  'FIBTG': {'label': 'Fiber, total dietary',
#   'quantity': 5.146000000000001,
#   'unit': 'g'},
#  'SUGAR': {'label': 'Sugars, total',
#   'quantity': 16.185000000000002,
#   'unit': 'g'},
#  'PROCNT': {'label': 'Protein', 'quantity': 0.5976, 'unit': 'g'},
#  'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#  'NA': {'label': 'Sodium, Na', 'quantity': 1.6600000000000001, 'unit': 'mg'},
#  'CA': {'label': 'Calcium, Ca', 'quantity': 14.940000000000001, 'unit': 'mg'},
#  'MG': {'label': 'Magnesium, Mg',
#   'quantity': 11.620000000000001,
#   'unit': 'mg'},
#  'K': {'label': 'Potassium, K', 'quantity': 192.56, 'unit': 'mg'},
#  'FE': {'label': 'Iron, Fe', 'quantity': 0.2988, 'unit': 'mg'},
#  'ZN': {'label': 'Zinc, Zn', 'quantity': 0.16600000000000004, 'unit': 'mg'},
#  'P': {'label': 'Phosphorus, P', 'quantity': 19.92, 'unit': 'mg'},
#  'VITA_RAE': {'label': 'Vitamin A, RAE',
#   'quantity': 1.6600000000000001,
#   'unit': 'µg'},
#  'VITC': {'label': 'Vitamin C, total ascorbic acid',
#   'quantity': 7.138,
#   'unit': 'mg'},
#  'THIA': {'label': 'Thiamin', 'quantity': 0.019920000000000004, 'unit': 'mg'},
#  'RIBF': {'label': 'Riboflavin',
#   'quantity': 0.043160000000000004,
#   'unit': 'mg'},
#  'NIA': {'label': 'Niacin', 'quantity': 0.26726000000000005, 'unit': 'mg'},
#  'VITB6A': {'label': 'Vitamin B-6',
#   'quantity': 0.04814000000000001,
#   'unit': 'mg'},
#  'FOLDFE': {'label': 'Folate, DFE',
#   'quantity': 11.620000000000001,
#   'unit': 'µg'},
#  'FOLFD': {'label': 'Folate, food',
#   'quantity': 11.620000000000001,
#   'unit': 'µg'},
#  'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#  'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#  'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#  'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#   'quantity': 0.19920000000000002,
#   'unit': 'mg'},
#  'VITK1': {'label': 'Vitamin K (phylloquinone)',
#   'quantity': 7.304000000000001,
#   'unit': 'µg'},
#  'WATER': {'label': 'Water', 'quantity': 139.3736, 'unit': 'g'}}

# %% [markdown]
# ### me devuelve un df con los valores de manzana vacíos y los valores de los otros dos ingredientes que si se encontraban en la API completados.

# %% [markdown]
# ### pero cuando le incluyo mi lista_food de ingredientes de mi df, y modifico la url poniendo en el parámetro de ingr, en lugar de apple, {ingre}, se queda colgado.

# %%
def call_api(app_id, app_key, lista_food):
    result_list = []
    for ingre in lista_food: 
        b = requests.get(f'https://api.edamam.com/api/nutrition-data?app_id={app_id}&app_key={app_key}&nutrition-type=logging&ingr={ingre}').content
        r = json.loads(b.decode())#me devuelve el string de un diccionario solo en diccionario
        result_list.append(r)
    return result_list

# %%
prueba2 = call_api('5bb5f3ad','a3a514dbb62d9ea04d57160922fce573',lista_food[:10])

# %%
prueba2
# Out:
# [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_df944a29d143461e9f4073c1fcbdfb70',
#   'calories': 126,
#   'totalWeight': 60.63315626628825,
#   'dietLabels': ['LOW_CARB', 'LOW_SODIUM'],
#   'healthLabels': ['SUGAR_CONSCIOUS',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_SUGAR_ADDED',
#    'KOSHER'],
#   'cautions': ['MILK'],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 126.94730600000003,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)',
#     'quantity': 11.603007560000002,
#     'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 7.314919952000001,
#     'unit': 'g'},
#    'FATRN': {'label': 'Fatty acids, total trans',
#     'quantity': 0.4654760000000001,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 2.9887966340000007,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.4688983880000001,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 5.635113700000001,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary',
#     'quantity': 2.4306918000000004,
#     'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total',
#     'quantity': 0.4653758400000001,
#     'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 1.73636434, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 30.530000000000005,
#     'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 140.41387768800004, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca',
#     'quantity': 28.618671503909184,
#     'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg',
#     'quantity': 27.14535156266288,
#     'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 176.9583785013031, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.6226096956787514, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.2606816962662883, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P',
#     'quantity': 46.98334800000001,
#     'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE',
#     'quantity': 97.60676200000002,
#     'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 5.9670000000000005,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin',
#     'quantity': 0.037865048000000005,
#     'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.03683308, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.4788082580000001, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6',
#     'quantity': 0.08788154600000002,
#     'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE',
#     'quantity': 29.786702000000005,
#     'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food',
#     'quantity': 29.786702000000005,
#     'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12',
#     'quantity': 0.024140000000000005,
#     'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)',
#     'quantity': 0.21300000000000002,
#     'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.41541823999999994,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 7.704642200000001,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 40.852087872532586, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 6.347365300000002,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 17.850780861538464, 'unit': '%'},
#    'FASAT': {'label': 'Saturated',
#     'quantity': 36.574599760000005,
#     'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 1.8783712333333336, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 9.722767200000002, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 3.4727286800000003, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 10.176666666666668,
#     'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 5.850578237000002, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 2.861867150390918, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 6.463178943491163, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 3.7650718830064487, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 3.458942753770841, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 2.369833602420803, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 6.711906857142858, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 10.84519577777778,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 6.630000000000001, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 3.155420666666667,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 2.833313846153846,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)',
#     'quantity': 2.9925516125000007,
#     'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 6.7601189230769245,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 7.446675500000001,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12',
#     'quantity': 1.0058333333333336,
#     'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 1.4200000000000002, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 2.769454933333333,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 6.420535166666667,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 127,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 7,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 99, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 21,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_77f4a2c74f1f40c2809e589dfb2137b9',
#   'calories': 25,
#   'totalWeight': 100.0,
#   'dietLabels': ['LOW_SODIUM'],
#   'healthLabels': ['FAT_FREE',
#    'LOW_FAT_ABS',
#    'SUGAR_CONSCIOUS',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'SPECIFIC_CARBS',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'FODMAP_FREE',
#    'KOSHER'],
#   'cautions': [],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 25.0,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.66, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.086,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 0.049,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.319,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 3.65,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 1.6, 'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 2.05, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 2.58, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 27.0, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 160.0, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg', 'quantity': 47.0, 'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 369.0, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 1.46, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.47, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 52.0, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 119.0, 'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 15.0,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.044, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.086, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.305, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.073, 'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 97.0, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 97.0, 'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.43,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 108.6,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 91.71, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 1.25,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 1.0153846153846153, 'unit': '%'},
#    'FASAT': {'label': 'Saturated', 'quantity': 0.43, 'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 1.2166666666666666, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 6.4, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 5.16, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 1.125, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 16.0, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 11.19047619047619, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 7.851063829787234, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 8.11111111111111, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 4.2727272727272725, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 7.428571428571429, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 13.222222222222221,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 16.666666666666668, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 3.6666666666666665,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 6.615384615384615,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 1.90625, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 5.615384615384615,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 24.25,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 2.8666666666666667,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K', 'quantity': 90.5, 'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 25,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 8,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 5, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 12,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_56a30aae3dc4493ea41c0d35abec4b74',
#   'calories': 99,
#   'totalWeight': 71.34979316880283,
#   'dietLabels': ['LOW_CARB', 'LOW_SODIUM'],
#   'healthLabels': ['SUGAR_CONSCIOUS',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'EGG_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'KOSHER'],
#   'cautions': ['GLUTEN', 'WHEAT', 'MILK'],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 99.55716645,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 8.657737377, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 2.1213174984000003,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 5.4593092940500005,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.7815267921000002,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 2.6414943525,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary',
#     'quantity': 1.2959874350000002,
#     'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 1.143482528, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 3.8100447905, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 4.8212, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 165.52277126460004, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 99.2574804105127, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg',
#     'quantity': 11.48786943168803,
#     'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 124.6159264035042, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 1.3329523684570495, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.5047053486688029, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 79.0459741, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE',
#     'quantity': 36.26628165,
#     'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 3.816,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.0842687766, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.104163261, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.57743978985, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6',
#     'quantity': 0.05946017444999999,
#     'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 30.04249215, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 30.04249215, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.08508, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.03545, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 1.627549608,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 28.088539115000007,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 55.2881395133376, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 4.9778583225,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 13.319595964615385, 'unit': '%'},
#    'FASAT': {'label': 'Saturated',
#     'quantity': 10.606587492000001,
#     'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 0.8804981175000001, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 5.18394974, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 7.620089580999999, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 1.6070666666666666,
#     'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 6.896782136025002, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 9.92574804105127, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 2.7352070075447688, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 2.6514026894362597, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 7.405290935872497, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 4.588230442443663, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 11.292282014285714, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A', 'quantity': 4.02958685, 'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 4.239999999999999, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 7.0223980500000005,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 8.012558538461537,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 3.6089986865625, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 4.5738595730769225,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 7.5106230375,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12',
#     'quantity': 3.5450000000000004,
#     'unit': '%'},
#    'VITD': {'label': 'Vitamin D',
#     'quantity': 0.23633333333333337,
#     'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 10.850330719999999,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 23.40711592916667,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 100,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 15,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 75, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 10,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_0dee23dbe3824101931d0caade667a2a',
#   'calories': 34,
#   'totalWeight': 99.0,
#   'dietLabels': ['LOW_FAT', 'LOW_SODIUM'],
#   'healthLabels': ['FAT_FREE',
#    'LOW_FAT_ABS',
#    'SUGAR_CONSCIOUS',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'FODMAP_FREE',
#    'KOSHER'],
#   'cautions': [],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 34.65,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.2277, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.043559999999999995,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 0.0198,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.09207,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 8.6427,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 2.475, 'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 3.168, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 0.8217, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 0.99, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca',
#     'quantity': 5.9399999999999995,
#     'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg', 'quantity': 10.89, 'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 121.77, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.2475, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.11879999999999999, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 14.85, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 1.98, 'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 1.287,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.07524, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.0198, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.594, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.08514, 'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 13.86, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 13.86, 'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.4059,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 2.871,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 88.7733, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 1.7325,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 0.3503076923076924, 'unit': '%'},
#    'FASAT': {'label': 'Saturated', 'quantity': 0.2178, 'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 2.8809, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 9.9, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 1.6434, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 0.04125, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 0.594, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 2.592857142857143, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 2.590851063829787, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 1.375, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 1.0799999999999998, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 2.1214285714285714, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A', 'quantity': 0.22, 'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 1.43, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 6.2700000000000005,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 1.5230769230769232,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 3.7125, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 6.5492307692307685,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 3.465,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E', 'quantity': 2.706, 'unit': '%'},
#    'VITK1': {'label': 'Vitamin K', 'quantity': 2.3925, 'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 35,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 3,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 2, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 30,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_56f5616fdec04db8bd5b77daded03d3e',
#   'calories': 43,
#   'totalWeight': 100.0,
#   'dietLabels': ['LOW_FAT', 'LOW_SODIUM'],
#   'healthLabels': ['FAT_FREE',
#    'LOW_FAT_ABS',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'SPECIFIC_CARBS',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'KOSHER'],
#   'cautions': [],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 43.0,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.17, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.027,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 0.032,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.06,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 9.56,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 2.8, 'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 6.76, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 1.61, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 78.0, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 16.0, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg', 'quantity': 23.0, 'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 325.0, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.8, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.35, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 40.0, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 2.0, 'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 4.9,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.031, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.04, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.334, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.067, 'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 109.0, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 109.0, 'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.04,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 0.2,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 87.58, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 2.15,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 0.26153846153846155, 'unit': '%'},
#    'FASAT': {'label': 'Saturated', 'quantity': 0.135, 'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 3.1866666666666665, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 11.2, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 3.22, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 3.25, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 1.6, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 5.476190476190476, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 6.914893617021277, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 4.444444444444445, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 3.1818181818181817, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 5.714285714285714, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 0.2222222222222222,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 5.444444444444445, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 2.5833333333333335,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 3.0769230769230766,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 2.0875, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 5.153846153846154,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 27.25,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 0.26666666666666666,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 0.16666666666666666,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 43,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 6,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 1, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 36,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_bf1fd12b48cc45a290eda8e660ad919c',
#   'calories': 3,
#   'totalWeight': 10.0,
#   'dietLabels': ['LOW_FAT', 'LOW_SODIUM'],
#   'healthLabels': ['FAT_FREE',
#    'LOW_FAT_ABS',
#    'SUGAR_CONSCIOUS',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'SPECIFIC_CARBS',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'FODMAP_FREE',
#    'KOSHER'],
#   'cautions': [],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 3.1,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.03, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.0027,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 0.00030000000000000003,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.007000000000000001,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 0.6030000000000001,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary',
#     'quantity': 0.21000000000000002,
#     'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total',
#     'quantity': 0.42000000000000004,
#     'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 0.099, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 0.4, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca',
#     'quantity': 0.7000000000000001,
#     'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg',
#     'quantity': 1.2000000000000002,
#     'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 21.1, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.043000000000000003, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.025, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 2.6, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE',
#     'quantity': 15.700000000000001,
#     'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 12.770000000000001,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.0054, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.0085, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.0979, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.0291, 'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE',
#     'quantity': 4.6000000000000005,
#     'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food',
#     'quantity': 4.6000000000000005,
#     'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.15800000000000003,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 0.49000000000000005,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 9.221, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 0.155,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 0.046153846153846156, 'unit': '%'},
#    'FASAT': {'label': 'Saturated',
#     'quantity': 0.013500000000000002,
#     'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 0.20100000000000004, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 0.8400000000000002, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 0.198, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 0.016666666666666666, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 0.07, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 0.28571428571428575, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 0.44893617021276594, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 0.23888888888888893, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 0.22727272727272727, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 0.37142857142857144, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 1.7444444444444445,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 14.188888888888892, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 0.45000000000000007,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 0.6538461538461539,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)',
#     'quantity': 0.6118750000000001,
#     'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 2.2384615384615385,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 1.1500000000000001,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 1.0533333333333335,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 0.4083333333333334,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 2,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 0,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 0, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 2,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_b7b3014f4d814be18caa4a205363bac4',
#   'calories': 34,
#   'totalWeight': 30.0,
#   'dietLabels': ['LOW_CARB', 'LOW_SODIUM'],
#   'healthLabels': ['LOW_FAT_ABS',
#    'SUGAR_CONSCIOUS',
#    'LOW_SUGAR',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'SPECIFIC_CARBS',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'FODMAP_FREE',
#    'KOSHER'],
#   'cautions': ['SULFITES'],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 34.5,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)',
#     'quantity': 3.2039999999999997,
#     'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.4245,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 2.3664,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.2733,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 1.878,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 0.96, 'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 0.0, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 0.252, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 220.5, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 26.4, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg', 'quantity': 1.2, 'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 2.4, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.9899999999999999, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.066, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P',
#     'quantity': 0.8999999999999999,
#     'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 6.0, 'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 0.27,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.0009, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.0, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.011099999999999999, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6',
#     'quantity': 0.0026999999999999997,
#     'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 0.0, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 0.0, 'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.49499999999999994,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 0.42,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 23.996999999999996, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 1.725,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 4.929230769230769, 'unit': '%'},
#    'FASAT': {'label': 'Saturated',
#     'quantity': 2.1224999999999996,
#     'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 0.6259999999999999, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 3.84, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 0.504, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 9.1875, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 2.64, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 0.2857142857142857, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 0.05106382978723404, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 5.499999999999999, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 0.6000000000000001, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 0.12857142857142856, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 0.6666666666666666,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 0.3, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)', 'quantity': 0.075, 'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)', 'quantity': 0.0, 'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)',
#     'quantity': 0.06937499999999999,
#     'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 0.20769230769230765,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 0.0,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 3.2999999999999994,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K', 'quantity': 0.35, 'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 35,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 1,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 27, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 7,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_0ebd7f0f1a554504857eb3ad87fbcc83',
#   'calories': 50,
#   'totalWeight': 148.0,
#   'dietLabels': ['LOW_FAT', 'LOW_SODIUM'],
#   'healthLabels': ['FAT_FREE',
#    'LOW_FAT_ABS',
#    'SUGAR_CONSCIOUS',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'VEGAN',
#    'VEGETARIAN',
#    'PESCATARIAN',
#    'PALEO',
#    'SPECIFIC_CARBS',
#    'MEDITERRANEAN',
#    'DASH',
#    'DAIRY_FREE',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'MILK_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'RED_MEAT_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED',
#    'SULPHITE_FREE',
#    'FODMAP_FREE',
#    'KOSHER'],
#   'cautions': [],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 50.32,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.5476, 'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 0.05772,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 0.01628,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.05624,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 9.8272,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 3.848, 'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 2.516, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 4.1735999999999995, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 48.839999999999996, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 69.56, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg', 'quantity': 31.08, 'unit': 'mg'},
#    'K': {'label': 'Potassium, K', 'quantity': 467.68, 'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 1.0804, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.6068, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P',
#     'quantity': 97.67999999999999,
#     'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 45.88, 'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 132.016,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.10507999999999999, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.17316, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.94572, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.259, 'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 93.24, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 93.24, 'unit': 'µg'},
#    'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)', 'quantity': 0.0, 'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 1.1544,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 150.368,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 132.164, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 2.516,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 0.8424615384615385, 'unit': '%'},
#    'FASAT': {'label': 'Saturated', 'quantity': 0.2886, 'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 3.275733333333333, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 15.392000000000001, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 8.347199999999999, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 2.035, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 6.956, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 7.4, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 9.95063829787234, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 6.002222222222223, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 5.516363636363637, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 13.954285714285714, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 5.097777777777778,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 146.68444444444444, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 8.756666666666666,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 13.320000000000002,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 5.91075, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 19.923076923076923,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 23.31,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 7.696000000000001,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 125.30666666666666,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 50,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 14,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 4, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 32,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_70831db8571a48019f35ec9df3c44cc5',
#   'calories': 144,
#   'totalWeight': 157.62934249999998,
#   'dietLabels': ['LOW_SODIUM'],
#   'healthLabels': ['SUGAR_CONSCIOUS',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE'],
#   'cautions': ['MILK'],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 144.45261727500002,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)',
#     'quantity': 9.8586680275,
#     'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 4.28553431735,
#     'unit': 'g'},
#    'FATRN': {'label': 'Fatty acids, total trans',
#     'quantity': 0.232738,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 4.159995748775001,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.8171927065250001,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 12.132283653750001,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary',
#     'quantity': 4.433583765,
#     'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total',
#     'quantity': 3.0047530350000002,
#     'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 4.8393524015, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 16.165000000000003,
#     'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 218.39127312500003, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca',
#     'quantity': 56.541386349999996,
#     'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg',
#     'quantity': 28.774748775000003,
#     'unit': 'mg'},
#    'K': {'label': 'Potassium, K',
#     'quantity': 491.08064232500016,
#     'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 1.78688017, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.5634588635, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 92.328558825, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE',
#     'quantity': 96.00371265,
#     'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 98.41387862500001,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin', 'quantity': 0.17399109857500006, 'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin', 'quantity': 0.13370453325, 'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 1.3532929766250004, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6',
#     'quantity': 0.296024760075,
#     'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE', 'quantity': 72.428148925, 'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food', 'quantity': 72.428148925, 'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12',
#     'quantity': 0.012070000000000003,
#     'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)',
#     'quantity': 0.10650000000000001,
#     'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 1.666745714,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 219.21832997500005,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 128.6157283, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 7.222630863750002,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 15.167181580769231, 'unit': '%'},
#    'FASAT': {'label': 'Saturated', 'quantity': 21.42767158675, 'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 4.044094551250001, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 17.73433506, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 9.678704803, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 5.3883333333333345,
#     'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 9.099636380208334, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 5.654138634999999, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 6.851130660714286, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 10.448524304787238, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 9.927112055555556, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 5.122353304545454, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 13.189794117857144, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 10.667079183333334,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 109.3487540277778, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 14.499258214583337,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 10.284964096153846,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 8.458081103906252, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 22.771135390384615,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 18.10703723125,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12',
#     'quantity': 0.5029166666666668,
#     'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 0.7100000000000001, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 11.111638093333333,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 182.68194164583338,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 145,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 18,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 82, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 45,
#     'unit': 'kcal'}}},
#  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_be1fade3af434bc8aa02b437f8f86f3a',
#   'calories': 115,
#   'totalWeight': 113.90320017157748,
#   'dietLabels': ['LOW_CARB', 'LOW_SODIUM'],
#   'healthLabels': ['SUGAR_CONSCIOUS',
#    'LOW_POTASSIUM',
#    'KIDNEY_FRIENDLY',
#    'KETO_FRIENDLY',
#    'GLUTEN_FREE',
#    'WHEAT_FREE',
#    'EGG_FREE',
#    'PEANUT_FREE',
#    'TREE_NUT_FREE',
#    'SOY_FREE',
#    'FISH_FREE',
#    'SHELLFISH_FREE',
#    'PORK_FREE',
#    'CRUSTACEAN_FREE',
#    'CELERY_FREE',
#    'MUSTARD_FREE',
#    'SESAME_FREE',
#    'LUPINE_FREE',
#    'MOLLUSK_FREE',
#    'ALCOHOL_FREE',
#    'NO_OIL_ADDED',
#    'NO_SUGAR_ADDED'],
#   'cautions': ['MILK'],
#   'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 115.4825,
#     'unit': 'kcal'},
#    'FAT': {'label': 'Total lipid (fat)',
#     'quantity': 9.332581250000002,
#     'unit': 'g'},
#    'FASAT': {'label': 'Fatty acids, total saturated',
#     'quantity': 5.866249375000001,
#     'unit': 'g'},
#    'FAMS': {'label': 'Fatty acids, total monounsaturated',
#     'quantity': 2.693461875000001,
#     'unit': 'g'},
#    'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#     'quantity': 0.28122250000000004,
#     'unit': 'g'},
#    'CHOCDF': {'label': 'Carbohydrate, by difference',
#     'quantity': 3.9607,
#     'unit': 'g'},
#    'FIBTG': {'label': 'Fiber, total dietary',
#     'quantity': 1.3125000000000002,
#     'unit': 'g'},
#    'SUGAR': {'label': 'Sugars, total', 'quantity': 2.5957, 'unit': 'g'},
#    'PROCNT': {'label': 'Protein', 'quantity': 4.72514375, 'unit': 'g'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 33.90562500000001,
#     'unit': 'mg'},
#    'NA': {'label': 'Sodium, Na', 'quantity': 264.0873225000001, 'unit': 'mg'},
#    'CA': {'label': 'Calcium, Ca', 'quantity': 141.3423930411786, 'unit': 'mg'},
#    'MG': {'label': 'Magnesium, Mg',
#     'quantity': 11.935282001715775,
#     'unit': 'mg'},
#    'K': {'label': 'Potassium, K',
#     'quantity': 117.95663101372621,
#     'unit': 'mg'},
#    'FE': {'label': 'Iron, Fe', 'quantity': 0.3365055605662057, 'unit': 'mg'},
#    'ZN': {'label': 'Zinc, Zn', 'quantity': 0.6334469501715776, 'unit': 'mg'},
#    'P': {'label': 'Phosphorus, P', 'quantity': 95.856875, 'unit': 'mg'},
#    'VITA_RAE': {'label': 'Vitamin A, RAE',
#     'quantity': 53.375625000000014,
#     'unit': 'µg'},
#    'VITC': {'label': 'Vitamin C, total ascorbic acid',
#     'quantity': 19.304625,
#     'unit': 'mg'},
#    'THIA': {'label': 'Thiamin',
#     'quantity': 0.039075000000000006,
#     'unit': 'mg'},
#    'RIBF': {'label': 'Riboflavin',
#     'quantity': 0.07646687500000002,
#     'unit': 'mg'},
#    'NIA': {'label': 'Niacin', 'quantity': 0.15898875, 'unit': 'mg'},
#    'VITB6A': {'label': 'Vitamin B-6',
#     'quantity': 0.07802750000000001,
#     'unit': 'mg'},
#    'FOLDFE': {'label': 'Folate, DFE',
#     'quantity': 24.492500000000003,
#     'unit': 'µg'},
#    'FOLFD': {'label': 'Folate, food',
#     'quantity': 24.492500000000003,
#     'unit': 'µg'},
#    'VITB12': {'label': 'Vitamin B-12',
#     'quantity': 0.19487500000000002,
#     'unit': 'µg'},
#    'VITD': {'label': 'Vitamin D (D2 + D3)',
#     'quantity': 0.17212500000000003,
#     'unit': 'µg'},
#    'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#     'quantity': 0.24980000000000002,
#     'unit': 'mg'},
#    'VITK1': {'label': 'Vitamin K (phylloquinone)',
#     'quantity': 40.6993125,
#     'unit': 'µg'},
#    'WATER': {'label': 'Water', 'quantity': 94.43226890034317, 'unit': 'g'}},
#   'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 5.774125,
#     'unit': '%'},
#    'FAT': {'label': 'Fat', 'quantity': 14.35781730769231, 'unit': '%'},
#    'FASAT': {'label': 'Saturated',
#     'quantity': 29.331246875000005,
#     'unit': '%'},
#    'CHOCDF': {'label': 'Carbs', 'quantity': 1.3202333333333334, 'unit': '%'},
#    'FIBTG': {'label': 'Fiber', 'quantity': 5.250000000000001, 'unit': '%'},
#    'PROCNT': {'label': 'Protein', 'quantity': 9.4502875, 'unit': '%'},
#    'CHOLE': {'label': 'Cholesterol',
#     'quantity': 11.301875000000003,
#     'unit': '%'},
#    'NA': {'label': 'Sodium', 'quantity': 11.003638437500003, 'unit': '%'},
#    'CA': {'label': 'Calcium', 'quantity': 14.13423930411786, 'unit': '%'},
#    'MG': {'label': 'Magnesium', 'quantity': 2.8417338099323275, 'unit': '%'},
#    'K': {'label': 'Potassium', 'quantity': 2.5097155534835363, 'unit': '%'},
#    'FE': {'label': 'Iron', 'quantity': 1.8694753364789203, 'unit': '%'},
#    'ZN': {'label': 'Zinc', 'quantity': 5.758608637923433, 'unit': '%'},
#    'P': {'label': 'Phosphorus', 'quantity': 13.693839285714287, 'unit': '%'},
#    'VITA_RAE': {'label': 'Vitamin A',
#     'quantity': 5.930625000000002,
#     'unit': '%'},
#    'VITC': {'label': 'Vitamin C', 'quantity': 21.449583333333333, 'unit': '%'},
#    'THIA': {'label': 'Thiamin (B1)',
#     'quantity': 3.2562500000000005,
#     'unit': '%'},
#    'RIBF': {'label': 'Riboflavin (B2)',
#     'quantity': 5.882067307692308,
#     'unit': '%'},
#    'NIA': {'label': 'Niacin (B3)', 'quantity': 0.9936796875, 'unit': '%'},
#    'VITB6A': {'label': 'Vitamin B6',
#     'quantity': 6.002115384615386,
#     'unit': '%'},
#    'FOLDFE': {'label': 'Folate equivalent (total)',
#     'quantity': 6.123125000000001,
#     'unit': '%'},
#    'VITB12': {'label': 'Vitamin B12',
#     'quantity': 8.119791666666668,
#     'unit': '%'},
#    'VITD': {'label': 'Vitamin D', 'quantity': 1.1475000000000002, 'unit': '%'},
#    'TOCPHA': {'label': 'Vitamin E',
#     'quantity': 1.6653333333333336,
#     'unit': '%'},
#    'VITK1': {'label': 'Vitamin K',
#     'quantity': 33.916093749999995,
#     'unit': '%'}},
#   'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#     'quantity': 115,
#     'unit': 'kcal'},
#    'PROCNT_KCAL': {'label': 'Calories from protein',
#     'quantity': 18,
#     'unit': 'kcal'},
#    'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 82, 'unit': 'kcal'},
#    'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#     'quantity': 15,
#     'unit': 'kcal'}}}]
