# %%
import requests 
import json
import os
from dotenv import load_dotenv
import pandas as pd
from pandas import json_normalize

# %%
# !pip3 install python-dotenv

# %%
df= pd.read_csv("../data/Food and Calories.csv")

# %%
#url = "https://www.fruityvice.com/api/fruit/all"

# %%
#response = requests.get(url)

# %%
#response
# Out:
# <Response [200]>

# %%
#res_js= response.json()

# %%
#res_js
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Fragaria',
#   'name': 'Blueberry',
#   'id': 33,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 5.5,
#    'protein': 0,
#    'fat': 0.4,
#    'calories': 29,
#    'sugar': 5.4}},
#  {'genus': 'Prunus',
#   'name': 'Cherry',
#   'id': 9,
# ...

# %%
#len(res_js)
# Out:
# 21

# %%
#res_js[0]
# Out:
# {'genus': 'Malus',
#  'name': 'Apple',
#  'id': 6,
#  'family': 'Rosaceae',
#  'order': 'Rosales',
#  'nutritions': {'carbohydrates': 11.4,
#   'protein': 0.3,
#   'fat': 0.4,
#   'calories': 52,
#   'sugar': 10.3}}

# %%
df.head()
# Out:
#         Food              Serving Calories
# 0  Artichoke  1 artichoke (128 g)   60 cal
# 1    Arugula         1 leaf (2 g)    1 cal
# 2  Asparagus       1 spear (12 g)    2 cal
# 3  Aubergine  1 aubergine (458 g)  115 cal
# 4   Beetroot        1 beet (82 g)   35 cal

# %%
df.shape
# Out:
# (562, 3)

# %%
df.dropna(how="all", inplace=True)

# %%
df.shape #no hay ninguna fila entera de NaN
# Out:
# (562, 3)

# %%
duplicates= df.drop_duplicates() #elimino los duplicados

# %%
duplicates.shape
# Out:
# (549, 3)

# %%
food = duplicates["Food"].unique()

# %%
lista_food= list(food)

# %%
type(lista_food)
# Out:
# list

# %%
lista_food
# Out:
# ['Artichoke',
#  'Arugula',
#  'Asparagus',
#  'Aubergine',
#  'Beetroot',
#  'Bell Pepper',
#  'Black Olives',
#  'Broccoli',
#  'Brussels Sprouts',
#  'Cabbage',
#  'Capsicum',
#  'Carrot',
#  'Cauliflower',
#  'Celery',
#  'Chard',
#  'Cherry Tomato',
#  'Chicory',
#  'Chinese Cabbage',
#  'Chives',
#  'Collard Greens',
#  'Corn',
#  'Courgette',
#  'Creamed Spinach',
#  'Cucumber',
#  'Eggplant',
#  'Endive',
#  'Fennel',
#  'Garlic',
#  'Gherkin',
#  'Gourd',
#  'Green Beans',
#  'Green Olives',
#  'Green Onion',
#  'Horseradish',
#  'Kale',
#  'Kohlrabi',
#  'Kumara',
#  'Leek',
#  'Lettuce',
#  'Mushrooms',
#  'Mustard Greens',
#  'Nori',
#  'Okra',
#  'Olives',
#  'Onion',
#  'Parsnips',
#  'Peas',
#  'Pepper',
#  'Potato',
#  'Pumpkin',
#  'Radishes',
#  'Red Cabbage',
#  'Rutabaga',
#  'Shallots',
#  'Spinach',
#  'Squash',
#  'Sweet Potato',
#  'Tomato',
#  'Turnip Greens',
#  'Turnips',
#  'Wasabi',
#  'Winter Squash',
#  'Zucchini',
#  'Acai',
#  'Apple',
# ...

# %%
#url_nut = 'https://api.edamam.com/api/nutrition-data?app_id=5bb5f3ad&app_key=a3a514dbb62d9ea04d57160922fce573&nutrition-type=logging&ingr=lista_food'

# %%
url2= 'https://api.edamam.com/api/nutrition-data'

# %%
parameters = {"app_id": '5bb5f3ad', "app_key":'a3a514dbb62d9ea04d57160922fce573', 'ingr':'apple'}

# %%
response2 = requests.get(url2, params=parameters)

# %%
response2
# Out:
# <Response [200]>

# %%
api=response2.json()

# %%
api
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_9945eb607d19406f958b437ea18c664f',
#  'calories': 0,
#  'totalWeight': 0.0,
#  'dietLabels': [],
#  'healthLabels': ['VEGAN',
#   'VEGETARIAN',
#   'PESCATARIAN',
#   'PALEO',
#   'SPECIFIC_CARBS',
#   'MEDITERRANEAN',
#   'DASH',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE',
#   'KOSHER'],
#  'cautions': ['SULFITES'],
#  'totalNutrients': {},
#  'totalDaily': {},
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 0,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
#    'quantity': 0,
# ...

# %%
type(api)
# Out:
# dict

# %%
#def call_api(app_id, app_key, ingredientes): SOLO PARA APPLE
   #result_list = []
    #for ingre in ingredientes: 
        #b = requests.get(f'https://api.edamam.com/api/nutrition-data?app_id=5bb5f3ad&app_key=a3a514dbb62d9ea04d57160922fce573&nutrition-type=logging&ingr=apple').content
        #r = json.loads(b.decode())
        #result_list.append(r)
    #return result_list

# %%
def call_api(app_id, app_key, lista_food):
    result_list = []
    for ingre in lista_food: 
        b = requests.get(f'https://api.edamam.com/api/nutrition-data?app_id={app_id}&app_key={app_key}&nutrition-type=logging&ingr={ingre}').content
        r = json.loads(b.decode())
        result_list.append(r)
    return result_list

# %%
#parameters = {"app_id": '5bb5f3ad', "app_key":'a3a514dbb62d9ea04d57160922fce573', 'ingr':'orange'}

# %%
nutrition = requests.get(url2, params=parameters).json()

# %%
nutrition
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_4ecd8c73cd894bb5a080d6a4261dda31',
#  'calories': 0,
#  'totalWeight': 0.0,
#  'dietLabels': [],
#  'healthLabels': ['VEGAN',
#   'VEGETARIAN',
#   'PESCATARIAN',
#   'PALEO',
#   'SPECIFIC_CARBS',
#   'MEDITERRANEAN',
#   'DASH',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE',
#   'KOSHER'],
#  'cautions': ['SULFITES'],
#  'totalNutrients': {},
#  'totalDaily': {},
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 0,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
#    'quantity': 0,
# ...

# %%
#'https://api.edamam.com/api/nutrition-data?app_id={app_id}&app_key={app_key}&nutrition-type=logging&ingr=AQUIELINGREDIENTEQUEQUIERAS'

# %%
para_json = requests.get(url_nut).json()
para_json
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_d091267f37624c2b935070273783506d',
#  'calories': 0,
#  'totalWeight': 0.0,
#  'dietLabels': [],
#  'healthLabels': ['LOW_SUGAR',
#   'VEGAN',
#   'VEGETARIAN',
#   'PESCATARIAN',
#   'PALEO',
#   'SPECIFIC_CARBS',
#   'MEDITERRANEAN',
#   'DASH',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE',
#   'FODMAP_FREE',
#   'KOSHER'],
#  'cautions': [],
#  'totalNutrients': {},
#  'totalDaily': {},
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 0,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
# ...

# %%
df_api= json_normalize(para_json)

# %%
df_api
# Out:
#                                                  uri  calories  totalWeight  \
# 0  http://www.edamam.com/ontologies/edamam.owl#re...         0          0.0
#
#   dietLabels                                       healthLabels cautions  \
# 0         []  [LOW_SUGAR, VEGAN, VEGETARIAN, PESCATARIAN, PA...       []
#
#   totalNutrientsKCal.ENERC_KCAL.label  totalNutrientsKCal.ENERC_KCAL.quantity  \
# 0                              Energy                                       0
#
#   totalNutrientsKCal.ENERC_KCAL.unit totalNutrientsKCal.PROCNT_KCAL.label  \
# 0                               kcal                Calories from protein
#
#    totalNutrientsKCal.PROCNT_KCAL.quantity  \
# 0                                        0
#
#   totalNutrientsKCal.PROCNT_KCAL.unit totalNutrientsKCal.FAT_KCAL.label  \
# 0                                kcal                 Calories from fat
#
#    totalNutrientsKCal.FAT_KCAL.quantity totalNutrientsKCal.FAT_KCAL.unit  \
# ...

# %%
#df_union = df.join(df_api, lsuffix="_df", rsuffix="_dfapi")

# %%
#df_union.head(25

# %%
lista_alimentos=[]
for i in lista_food:
    try:
        'https://api.edamam.com/api/nutrition-data?app_id={app_id}&app_key={app_key}&nutrition-type=logging&ingr={ingre}'
        #tienes que ir haciendo append a un dataframe que crees o guardarlo de alguna manera
    except:
        pass #este except hace que si no existe el endpoint de algun alimento no de error y continue con el siguiente
